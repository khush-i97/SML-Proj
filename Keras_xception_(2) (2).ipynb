# %%
import pandas as pd

df = pd.read_csv('ham10000/HAM10000_metadata.csv')
df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
import os
import pandas as pd
from glob import glob

# Paths
dataset_path = "ham10000"
csv_path = os.path.join(dataset_path, "HAM10000_metadata.csv")
image_dir_1 = os.path.join(dataset_path, "HAM10000_images_part_1")
image_dir_2 = os.path.join(dataset_path, "HAM10000_images_part_2")


df = pd.read_csv(csv_path)


all_image_paths = glob(os.path.join(image_dir_1, '*.jpg')) + glob(os.path.join(image_dir_2, '*.jpg'))


imageid_path_dict = {
    os.path.splitext(os.path.basename(path))[0]: path
    for path in all_image_paths
}


df['image_path'] = df['image_id'].map(imageid_path_dict)


df = df[df['image_path'].notnull()]

print(f" Combined dataset shape: {df.shape}")
print(df[['image_id', 'image_path']].head())
# Out:
#  Combined dataset shape: (10015, 8)
#        image_id                                        image_path
# 0  ISIC_0027419  ham10000/HAM10000_images_part_1/ISIC_0027419.jpg
# 1  ISIC_0025030  ham10000/HAM10000_images_part_1/ISIC_0025030.jpg
# 2  ISIC_0026769  ham10000/HAM10000_images_part_1/ISIC_0026769.jpg
# 3  ISIC_0025661  ham10000/HAM10000_images_part_1/ISIC_0025661.jpg
# 4  ISIC_0031633  ham10000/HAM10000_images_part_2/ISIC_0031633.jpg

# %%
df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#                                          image_path
# 0  ham10000/HAM10000_images_part_1/ISIC_0027419.jpg
# 1  ham10000/HAM10000_images_part_1/ISIC_0025030.jpg
# 2  ham10000/HAM10000_images_part_1/ISIC_0026769.jpg
# 3  ham10000/HAM10000_images_part_1/ISIC_0025661.jpg
# 4  ham10000/HAM10000_images_part_2/ISIC_0031633.jpg

# %%
print(f" Total entries in df: {df.shape[0]}")
print(f" Columns in df: {df.shape[1]}")
# Out:
#  Total entries in df: 10015
#  Columns in df: 8

# %%
print("Image count per original class (dx):")
print(df['dx'].value_counts())
# Out:
# Image count per original class (dx):
# dx
# nv       6705
# mel      1113
# bkl      1099
# bcc       514
# akiec     327
# vasc      142
# df        115
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder


le = LabelEncoder()
df['label'] = le.fit_transform(df['dx'])


print("Encoded class labels:", dict(zip(le.classes_, range(len(le.classes_)))))
# Out:
# Encoded class labels: {'akiec': 0, 'bcc': 1, 'bkl': 2, 'df': 3, 'mel': 4, 'nv': 5, 'vasc': 6}

# %%
from sklearn.model_selection import train_test_split

#Splitting 10% for test
train_val_df, test_df = train_test_split(
    df,
    test_size=0.10,  # 10% test
    stratify=df['label'],
    random_state=42
)



train_df, val_df = train_test_split(
    train_val_df,
    test_size=0.222,
    stratify=train_val_df['label'],
    random_state=42
)


print("Train class distribution:\n", train_df['label'].value_counts())
print("\nVal class distribution:\n", val_df['label'].value_counts())
print("\nTest class distribution:\n", test_df['label'].value_counts())
# Out:
# Train class distribution:
#  label
# 5    4694
# 4     780
# 2     769
# 1     360
# 0     229
# 6     100
# 3      80
# Name: count, dtype: int64
#
# Val class distribution:
#  label
# 5    1340
# 4     222
# 2     220
# 1     103
# 0      65
# 6      28
# 3      23
# Name: count, dtype: int64
#
# Test class distribution:
#  label
# 5    671
# 4    111
# 2    110
# 1     51
# 0     33
# 6     14
# 3     12
# Name: count, dtype: int64

# %%
import tensorflow as tf
from tensorflow.keras.applications import Xception
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.applications import Xception
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, GlobalAveragePooling2D, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam


INPUT_SHAPE = (299, 299, 3)
BATCH_SIZE = 32
EPOCHS = 20
NUM_CLASSES = len(df['label'].unique())




train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='image_path',
    y_col='dx',
    target_size=INPUT_SHAPE[:2],
    batch_size=BATCH_SIZE,
    class_mode='sparse',
    shuffle=True,
    seed=42
)

val_generator = val_test_datagen.flow_from_dataframe(
    dataframe=val_df,
    x_col='image_path',
    y_col='dx',
    target_size=INPUT_SHAPE[:2],
    batch_size=BATCH_SIZE,
    class_mode='sparse',
    shuffle=False,
    seed=42
)

test_generator = val_test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='image_path',
    y_col='dx',
    target_size=INPUT_SHAPE[:2],
    batch_size=BATCH_SIZE,
    class_mode='sparse',
    shuffle=False,
    seed=42
)
# Out:
# Found 7012 validated image filenames belonging to 7 classes.
# Found 2001 validated image filenames belonging to 7 classes.
# Found 1002 validated image filenames belonging to 7 classes.

# %%
# Building custom Xception model
def build_xception_model(input_shape=(299, 299, 3), num_classes=7):
    base_model = Xception(weights='imagenet', include_top=False, input_tensor=Input(shape=input_shape))
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=outputs)
    model.compile(optimizer=Adam(1e-4), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# Callbacks
checkpoint = ModelCheckpoint("xception_best_model_final.h5", monitor='val_accuracy', save_best_only=True, verbose=1)
early_stop = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True, verbose=1)

# Training
model = build_xception_model(INPUT_SHAPE, NUM_CLASSES)
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[checkpoint, early_stop]
)
# Out:
# 2025-04-18 11:47:50.766782: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 79195 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:41:00.0, compute capability: 8.0
# Epoch 1/20
# 2025-04-18 11:48:00.860863: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2025-04-18 11:48:00.941999: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2025-04-18 11:48:01.088437: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2025-04-18 11:48:03.036751: I external/local_xla/xla/service/service.cc:168] XLA service 0x15533e115af0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-04-18 11:48:03.036790: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A100-SXM4-80GB, Compute Capability 8.0
# 2025-04-18 11:48:03.041471: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745002083.106295 2426961 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 220/220 [==============================] - ETA: 0s - loss: 1.7039 - accuracy: 0.5501
# Epoch 1: val_accuracy improved from -inf to 0.73663, saving model to xception_best_model_final.h5
# /packages/envs/tensorflow-gpu-2.15.0/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 220/220 [==============================] - 133s 520ms/step - loss: 1.7039 - accuracy: 0.5501 - val_loss: 1.0832 - val_accuracy: 0.7366
# Epoch 2/20
# 220/220 [==============================] - ETA: 0s - loss: 1.0001 - accuracy: 0.7346
# Epoch 2: val_accuracy improved from 0.73663 to 0.77611, saving model to xception_best_model_final.h5
# 220/220 [==============================] - 116s 527ms/step - loss: 1.0001 - accuracy: 0.7346 - val_loss: 0.9295 - val_accuracy: 0.7761
# Epoch 3/20
# 220/220 [==============================] - ETA: 0s - loss: 0.7969 - accuracy: 0.7809
# Epoch 3: val_accuracy improved from 0.77611 to 0.81109, saving model to xception_best_model_final.h5
# 220/220 [==============================] - 115s 523ms/step - loss: 0.7969 - accuracy: 0.7809 - val_loss: 0.6900 - val_accuracy: 0.8111
# Epoch 4/20
# 220/220 [==============================] - ETA: 0s - loss: 0.6696 - accuracy: 0.8022
# Epoch 4: val_accuracy improved from 0.81109 to 0.82409, saving model to xception_best_model_final.h5
# 220/220 [==============================] - 113s 514ms/step - loss: 0.6696 - accuracy: 0.8022 - val_loss: 0.6481 - val_accuracy: 0.8241
# Epoch 5/20
# 220/220 [==============================] - ETA: 0s - loss: 0.5502 - accuracy: 0.8319
# Epoch 5: val_accuracy did not improve from 0.82409
# 220/220 [==============================] - 113s 513ms/step - loss: 0.5502 - accuracy: 0.8319 - val_loss: 0.8320 - val_accuracy: 0.7991
# Epoch 6/20
# 220/220 [==============================] - ETA: 0s - loss: 0.4945 - accuracy: 0.8438
# Epoch 6: val_accuracy improved from 0.82409 to 0.82559, saving model to xception_best_model_final.h5
# 220/220 [==============================] - 118s 537ms/step - loss: 0.4945 - accuracy: 0.8438 - val_loss: 0.7038 - val_accuracy: 0.8256
# Epoch 7/20
# 220/220 [==============================] - ETA: 0s - loss: 0.4574 - accuracy: 0.8530
# Epoch 7: val_accuracy did not improve from 0.82559
# 220/220 [==============================] - 115s 523ms/step - loss: 0.4574 - accuracy: 0.8530 - val_loss: 0.8106 - val_accuracy: 0.8071
# Epoch 8/20
# 220/220 [==============================] - ETA: 0s - loss: 0.4285 - accuracy: 0.8634
# Epoch 8: val_accuracy did not improve from 0.82559
# 220/220 [==============================] - 115s 520ms/step - loss: 0.4285 - accuracy: 0.8634 - val_loss: 0.8265 - val_accuracy: 0.7741
# Epoch 9/20
# 220/220 [==============================] - ETA: 0s - loss: 0.3645 - accuracy: 0.8788
# Epoch 9: val_accuracy improved from 0.82559 to 0.83308, saving model to xception_best_model_final.h5
# 220/220 [==============================] - 116s 525ms/step - loss: 0.3645 - accuracy: 0.8788 - val_loss: 0.5405 - val_accuracy: 0.8331
# Epoch 10/20
# 220/220 [==============================] - ETA: 0s - loss: 0.3247 - accuracy: 0.8943
# Epoch 10: val_accuracy did not improve from 0.83308
# 220/220 [==============================] - 114s 517ms/step - loss: 0.3247 - accuracy: 0.8943 - val_loss: 0.9762 - val_accuracy: 0.7731
# Epoch 11/20
# 220/220 [==============================] - ETA: 0s - loss: 0.2949 - accuracy: 0.9005
# Epoch 11: val_accuracy did not improve from 0.83308
# 220/220 [==============================] - 114s 518ms/step - loss: 0.2949 - accuracy: 0.9005 - val_loss: 0.6910 - val_accuracy: 0.8261
# Epoch 12/20
# 220/220 [==============================] - ETA: 0s - loss: 0.2499 - accuracy: 0.9136
# Epoch 12: val_accuracy improved from 0.83308 to 0.83958, saving model to xception_best_model_final.h5
# 220/220 [==============================] - 116s 528ms/step - loss: 0.2499 - accuracy: 0.9136 - val_loss: 0.6212 - val_accuracy: 0.8396
# Epoch 13/20
# 220/220 [==============================] - ETA: 0s - loss: 0.2624 - accuracy: 0.9100
# Epoch 13: val_accuracy did not improve from 0.83958
# 220/220 [==============================] - 113s 514ms/step - loss: 0.2624 - accuracy: 0.9100 - val_loss: 0.8095 - val_accuracy: 0.8101
# Epoch 14/20
# 220/220 [==============================] - ETA: 0s - loss: 0.2000 - accuracy: 0.9305
# Epoch 14: val_accuracy did not improve from 0.83958
# 220/220 [==============================] - 112s 511ms/step - loss: 0.2000 - accuracy: 0.9305 - val_loss: 0.8393 - val_accuracy: 0.8266
# Epoch 15/20
# 220/220 [==============================] - ETA: 0s - loss: 0.2273 - accuracy: 0.9248
# Epoch 15: val_accuracy improved from 0.83958 to 0.84008, saving model to xception_best_model_final.h5
# 220/220 [==============================] - 116s 526ms/step - loss: 0.2273 - accuracy: 0.9248 - val_loss: 0.7331 - val_accuracy: 0.8401
# Epoch 16/20
# 220/220 [==============================] - ETA: 0s - loss: 0.1999 - accuracy: 0.9380
# Epoch 16: val_accuracy did not improve from 0.84008
# 220/220 [==============================] - 113s 513ms/step - loss: 0.1999 - accuracy: 0.9380 - val_loss: 0.9352 - val_accuracy: 0.8231
# Epoch 17/20
# 220/220 [==============================] - ETA: 0s - loss: 0.1880 - accuracy: 0.9391
# Epoch 17: val_accuracy did not improve from 0.84008
# 220/220 [==============================] - 111s 504ms/step - loss: 0.1880 - accuracy: 0.9391 - val_loss: 1.1233 - val_accuracy: 0.7571
# Epoch 18/20
# 220/220 [==============================] - ETA: 0s - loss: 0.2080 - accuracy: 0.9330
# Epoch 18: val_accuracy did not improve from 0.84008
# 220/220 [==============================] - 114s 520ms/step - loss: 0.2080 - accuracy: 0.9330 - val_loss: 0.8614 - val_accuracy: 0.8246
# Epoch 19/20
# 220/220 [==============================] - ETA: 0s - loss: 0.1623 - accuracy: 0.9420
# Epoch 19: val_accuracy did not improve from 0.84008
# 220/220 [==============================] - 113s 515ms/step - loss: 0.1623 - accuracy: 0.9420 - val_loss: 0.9299 - val_accuracy: 0.8386
# Epoch 20/20
# 220/220 [==============================] - ETA: 0s - loss: 0.1402 - accuracy: 0.9528
# Epoch 20: val_accuracy did not improve from 0.84008
# Restoring model weights from the end of the best epoch: 15.
# 220/220 [==============================] - 112s 510ms/step - loss: 0.1402 - accuracy: 0.9528 - val_loss: 1.0742 - val_accuracy: 0.8226
# Epoch 20: early stopping

# %%
# Plot training history
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Load best model
best_model = load_model("xception_best_model2.h5")

# Evaluate on test set
test_steps = test_generator.samples // test_generator.batch_size + 1
y_pred_probs = best_model.predict(test_generator, steps=test_steps)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_generator.classes

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix on Test Set')
plt.show()

# Classification Report
print(classification_report(y_true, y_pred, target_names=le.classes_))
# Out:
# 32/32 [==============================] - 8s 224ms/step
#               precision    recall  f1-score   support
#
#        akiec       0.83      0.58      0.68        33
#          bcc       0.92      0.67      0.77        51
#          bkl       0.69      0.78      0.73       110
#           df       0.67      0.83      0.74        12
#          mel       0.59      0.59      0.59       111
#           nv       0.92      0.92      0.92       671
#         vasc       0.80      0.86      0.83        14
#
#     accuracy                           0.84      1002
#    macro avg       0.77      0.75      0.75      1002
# weighted avg       0.85      0.84      0.84      1002

# %%
import random
from PIL import Image


filenames = test_generator.filenames
true_labels = y_true
pred_labels = y_pred


random_indices = random.sample(range(len(filenames)), 10)

# Display predictions
for i in random_indices:
    image_path = os.path.join(test_generator.directory, filenames[i])
    true_class = le.inverse_transform([true_labels[i]])[0]
    pred_class = le.inverse_transform([pred_labels[i]])[0]

    print(f"Image: {os.path.basename(image_path)}")
    print(f"True Label: {true_class} | Predicted: {pred_class}")

    img = Image.open(image_path)
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"True: {true_class} | Pred: {pred_class}")
    plt.show()
# Out:
# Image: ISIC_0030948.jpg
# True Label: nv | Predicted: nv
# Image: ISIC_0025260.jpg
# True Label: bcc | Predicted: bcc
# Image: ISIC_0027093.jpg
# True Label: bcc | Predicted: bcc
# Image: ISIC_0032870.jpg
# True Label: mel | Predicted: bkl
# Image: ISIC_0033449.jpg
# True Label: bkl | Predicted: bkl
# Image: ISIC_0028889.jpg
# True Label: nv | Predicted: nv
# Image: ISIC_0032423.jpg
# True Label: nv | Predicted: mel
# Image: ISIC_0031785.jpg
# True Label: nv | Predicted: nv
# Image: ISIC_0028894.jpg
# True Label: nv | Predicted: mel
# Image: ISIC_0025705.jpg
# True Label: nv | Predicted: nv

# %% [markdown]
# REFERENCES:
# 1. https://keras.io/api/applications/xception/
# 2. https://keras.io/api/applications/
# 3. https://www.tensorflow.org/tutorials/images/transfer_learning
# 4. https://www.geeksforgeeks.org/transfer-learning-fine-tuning-using-keras/#
